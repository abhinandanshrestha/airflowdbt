# %% [markdown]
# # Every 30min

# %%
import requests
from datetime import datetime, timedelta


API_URL = f'http://api.weatherapi.com/v1/current.json?key=7bf13464e9e04c8984f134342232606&q=Kathmandu&aqi=no'
# Make a request to the weather API
response = requests.get(API_URL)
response.raise_for_status()  # Raise an exception for HTTP errors

# If the response is successful, parse the JSON data
data = response.json()

data
# Out:
# {'location': {'name': 'Kathmandu',
#   'region': '',
#   'country': 'Nepal',
#   'lat': 27.7167,
#   'lon': 85.3167,
#   'tz_id': 'Asia/Kathmandu',
#   'localtime_epoch': 1745386579,
#   'localtime': '2025-04-23 11:21'},
#  'current': {'last_updated_epoch': 1745386200,
#   'last_updated': '2025-04-23 11:15',
#   'temp_c': 29.1,
#   'temp_f': 84.4,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 4.3,
#   'wind_kph': 6.8,
#   'wind_degree': 244,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1013.0,
#   'pressure_in': 29.91,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 27,
#   'cloud': 25,
#   'feelslike_c': 27.0,
#   'feelslike_f': 80.5,
#   'windchill_c': 30.5,
#   'windchill_f': 87.0,
#   'heatindex_c': 28.3,
#   'heatindex_f': 83.0,
#   'dewpoint_c': -1.3,
#   'dewpoint_f': 29.7,
#   'vis_km': 8.0,
#   'vis_miles': 4.0,
#   'uv': 11.2,
#   'gust_mph': 4.9,
#   'gust_kph': 7.9}}

# %%
import pandas as pd

# Flatten the data structure into a single dictionary for DataFrame
weather_data = {
    'location_name': data['location']['name'],
    'country': data['location']['country'],
    'lat': data['location']['lat'],
    'lon': data['location']['lon'],
    'tz_id': data['location']['tz_id'],
    'localtime_epoch': data['location']['localtime_epoch'],
    'localtime': datetime.fromtimestamp(data['location']['localtime_epoch']),
    'temperature_c': data['current']['temp_c'],
    'temperature_f': data['current']['temp_f'],
    'condition_text': data['current']['condition']['text'],
    'condition_code': data['current']['condition']['code'],
    'wind_mph': data['current']['wind_mph'],
    'wind_kph': data['current']['wind_kph'],
    'wind_degree': data['current']['wind_degree'],
    'wind_dir': data['current']['wind_dir'],
    'pressure_mb': data['current']['pressure_mb'],
    'precip_mm': data['current']['precip_mm'],
    'humidity': data['current']['humidity'],
    'cloud': data['current']['cloud'],
    'feelslike_c': data['current']['feelslike_c'],
    'feelslike_f': data['current']['feelslike_f'],
    'windchill_c': data['current']['windchill_c'],
    'windchill_f': data['current']['windchill_f'],
    'heatindex_c': data['current']['heatindex_c'],
    'heatindex_f': data['current']['heatindex_f'],
    'dewpoint_c': data['current']['dewpoint_c'],
    'dewpoint_f': data['current']['dewpoint_f'],
    'vis_km': data['current']['vis_km'],
    'vis_miles': data['current']['vis_miles'],
    'uv': data['current']['uv'],
    'gust_mph': data['current']['gust_mph'],
    'gust_kph': data['current']['gust_kph'],
    'last_updated_epoch': data['current']['last_updated_epoch'],
    'last_updated': datetime.fromtimestamp(data['current']['last_updated_epoch'])
}

# Create a pandas dataframe from the flattened dictionary
df = pd.DataFrame([weather_data])
df
# Out:
#   location_name country      lat      lon           tz_id  localtime_epoch  \
# 0     Kathmandu   Nepal  27.7167  85.3167  Asia/Kathmandu       1745386579
#
#             localtime  temperature_c  temperature_f condition_text  ...  \
# 0 2025-04-23 11:21:19           29.1           84.4          Sunny  ...
#
#    heatindex_f  dewpoint_c  dewpoint_f  vis_km vis_miles    uv  gust_mph  \
# 0         83.0        -1.3        29.7     8.0       4.0  11.2       4.9
#
#    gust_kph  last_updated_epoch        last_updated
# 0       7.9          1745386200 2025-04-23 11:15:00
#
# [1 rows x 34 columns]

# %% [markdown]
# # Every day

# %%
import requests
from datetime import datetime, timedelta


API_URL = f"http://api.weatherapi.com/v1/history.json?key=7bf13464e9e04c8984f134342232606&q=Kathmandu&dt=2025-04-16"
# Make a request to the weather API
response = requests.get(API_URL)
response.raise_for_status()  # Raise an exception for HTTP errors

# If the response is successful, parse the JSON data
data = response.json()

data
# Out:
# {'location': {'name': 'Kathmandu',
#   'region': '',
#   'country': 'Nepal',
#   'lat': 27.7167,
#   'lon': 85.3167,
#   'tz_id': 'Asia/Kathmandu',
#   'localtime_epoch': 1745397259,
#   'localtime': '2025-04-23 14:19'},
#  'forecast': {'forecastday': [{'date': '2025-04-16',
#     'date_epoch': 1744761600,
#     'day': {'maxtemp_c': 25.5,
#      'maxtemp_f': 77.9,
#      'mintemp_c': 16.5,
#      'mintemp_f': 61.7,
#      'avgtemp_c': 20.7,
#      'avgtemp_f': 69.3,
#      'maxwind_mph': 4.7,
#      'maxwind_kph': 7.6,
#      'totalprecip_mm': 1.3,
#      'totalprecip_in': 0.05,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 45,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 100,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 6.0},
#     'astro': {'sunrise': '05:38 AM',
#      'sunset': '06:29 PM',
#      'moonrise': '09:40 PM',
#      'moonset': '07:14 AM',
#      'moon_phase': 'Waning Gibbous',
#      'moon_illumination': 93},
#     'hour': [{'time_epoch': 1744740900,
#       'time': '2025-04-16 00:00',
#       'temp_c': 16.7,
#       'temp_f': 62.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 1.3,
#       'wind_kph': 2.2,
#       'wind_degree': 58,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 16,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.1,
#       'windchill_c': 16.7,
#       'windchill_f': 62.1,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.1,
#       'dewpoint_c': 10.8,
#       'dewpoint_f': 51.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.8,
#       'gust_kph': 4.5,
#       'uv': 0.0},
#      {'time_epoch': 1744744500,
#       'time': '2025-04-16 01:00',
#       'temp_c': 16.5,
#       'temp_f': 61.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 51,
#       'wind_dir': 'NE',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 18,
#       'feelslike_c': 16.5,
#       'feelslike_f': 61.7,
#       'windchill_c': 16.5,
#       'windchill_f': 61.7,
#       'heatindex_c': 16.5,
#       'heatindex_f': 61.7,
#       'dewpoint_c': 10.5,
#       'dewpoint_f': 50.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.2,
#       'gust_kph': 6.8,
#       'uv': 0.0},
#      {'time_epoch': 1744748100,
#       'time': '2025-04-16 02:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 45,
#       'wind_dir': 'NE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 19,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 8.2,
#       'dewpoint_f': 46.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.1,
#       'uv': 0.0},
#      {'time_epoch': 1744751700,
#       'time': '2025-04-16 03:00',
#       'temp_c': 17.1,
#       'temp_f': 62.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 64,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 20,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.7,
#       'windchill_c': 17.1,
#       'windchill_f': 62.7,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.7,
#       'dewpoint_c': 7.9,
#       'dewpoint_f': 46.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.2,
#       'gust_kph': 6.8,
#       'uv': 0.0},
#      {'time_epoch': 1744755300,
#       'time': '2025-04-16 04:00',
#       'temp_c': 17.0,
#       'temp_f': 62.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 81,
#       'wind_dir': 'E',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 20,
#       'feelslike_c': 17.0,
#       'feelslike_f': 62.6,
#       'windchill_c': 17.0,
#       'windchill_f': 62.6,
#       'heatindex_c': 17.0,
#       'heatindex_f': 62.6,
#       'dewpoint_c': 7.9,
#       'dewpoint_f': 46.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.0,
#       'uv': 0.0},
#      {'time_epoch': 1744758900,
#       'time': '2025-04-16 05:00',
#       'temp_c': 17.2,
#       'temp_f': 62.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 81,
#       'wind_dir': 'E',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 21,
#       'feelslike_c': 17.2,
#       'feelslike_f': 62.9,
#       'windchill_c': 17.2,
#       'windchill_f': 62.9,
#       'heatindex_c': 17.2,
#       'heatindex_f': 62.9,
#       'dewpoint_c': 8.0,
#       'dewpoint_f': 46.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.7,
#       'gust_kph': 6.0,
#       'uv': 0.0},
#      {'time_epoch': 1744762500,
#       'time': '2025-04-16 06:00',
#       'temp_c': 17.7,
#       'temp_f': 63.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 88,
#       'wind_dir': 'E',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 19,
#       'feelslike_c': 17.7,
#       'feelslike_f': 63.8,
#       'windchill_c': 17.7,
#       'windchill_f': 63.8,
#       'heatindex_c': 17.7,
#       'heatindex_f': 63.8,
#       'dewpoint_c': 11.2,
#       'dewpoint_f': 52.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.8,
#       'gust_kph': 4.5,
#       'uv': 5.0},
#      {'time_epoch': 1744766100,
#       'time': '2025-04-16 07:00',
#       'temp_c': 20.1,
#       'temp_f': 68.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 119,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 42,
#       'cloud': 18,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.1,
#       'windchill_c': 20.1,
#       'windchill_f': 68.1,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.1,
#       'dewpoint_c': 11.7,
#       'dewpoint_f': 53.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.3,
#       'gust_kph': 3.7,
#       'uv': 6.0},
#      {'time_epoch': 1744769700,
#       'time': '2025-04-16 08:00',
#       'temp_c': 21.8,
#       'temp_f': 71.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 167,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 38,
#       'cloud': 20,
#       'feelslike_c': 21.8,
#       'feelslike_f': 71.3,
#       'windchill_c': 21.8,
#       'windchill_f': 71.3,
#       'heatindex_c': 23.9,
#       'heatindex_f': 74.9,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.3,
#       'uv': 6.0},
#      {'time_epoch': 1744773300,
#       'time': '2025-04-16 09:00',
#       'temp_c': 23.5,
#       'temp_f': 74.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 205,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 35,
#       'cloud': 77,
#       'feelslike_c': 24.3,
#       'feelslike_f': 75.7,
#       'windchill_c': 23.5,
#       'windchill_f': 74.3,
#       'heatindex_c': 24.3,
#       'heatindex_f': 75.7,
#       'dewpoint_c': 11.3,
#       'dewpoint_f': 52.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.3,
#       'gust_kph': 8.5,
#       'uv': 5.0},
#      {'time_epoch': 1744776900,
#       'time': '2025-04-16 10:00',
#       'temp_c': 24.7,
#       'temp_f': 76.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 224,
#       'wind_dir': 'SW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 33,
#       'cloud': 71,
#       'feelslike_c': 24.8,
#       'feelslike_f': 76.6,
#       'windchill_c': 24.7,
#       'windchill_f': 76.5,
#       'heatindex_c': 24.8,
#       'heatindex_f': 76.6,
#       'dewpoint_c': 11.2,
#       'dewpoint_f': 52.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 10.0,
#       'uv': 5.0},
#      {'time_epoch': 1744780500,
#       'time': '2025-04-16 11:00',
#       'temp_c': 25.1,
#       'temp_f': 77.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 216,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.86,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 33,
#       'cloud': 71,
#       'feelslike_c': 25.0,
#       'feelslike_f': 77.0,
#       'windchill_c': 25.1,
#       'windchill_f': 77.1,
#       'heatindex_c': 25.0,
#       'heatindex_f': 77.0,
#       'dewpoint_c': 10.8,
#       'dewpoint_f': 51.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.9,
#       'gust_kph': 11.1,
#       'uv': 6.0},
#      {'time_epoch': 1744784100,
#       'time': '2025-04-16 12:00',
#       'temp_c': 25.5,
#       'temp_f': 77.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 208,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.3,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 35,
#       'cloud': 76,
#       'feelslike_c': 25.4,
#       'feelslike_f': 77.7,
#       'windchill_c': 25.5,
#       'windchill_f': 77.9,
#       'heatindex_c': 25.4,
#       'heatindex_f': 77.7,
#       'dewpoint_c': 8.8,
#       'dewpoint_f': 47.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.1,
#       'uv': 6.0},
#      {'time_epoch': 1744787700,
#       'time': '2025-04-16 13:00',
#       'temp_c': 25.3,
#       'temp_f': 77.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 216,
#       'wind_dir': 'SW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.81,
#       'precip_mm': 0.3,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 36,
#       'cloud': 82,
#       'feelslike_c': 25.3,
#       'feelslike_f': 77.6,
#       'windchill_c': 25.3,
#       'windchill_f': 77.6,
#       'heatindex_c': 25.3,
#       'heatindex_f': 77.6,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.1,
#       'gust_kph': 14.6,
#       'uv': 6.0},
#      {'time_epoch': 1744791300,
#       'time': '2025-04-16 14:00',
#       'temp_c': 25.5,
#       'temp_f': 77.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 226,
#       'wind_dir': 'SW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.78,
#       'precip_mm': 0.2,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 37,
#       'cloud': 89,
#       'feelslike_c': 25.5,
#       'feelslike_f': 77.9,
#       'windchill_c': 25.5,
#       'windchill_f': 77.9,
#       'heatindex_c': 25.5,
#       'heatindex_f': 77.9,
#       'dewpoint_c': 9.6,
#       'dewpoint_f': 49.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.2,
#       'gust_kph': 19.6,
#       'uv': 6.0},
#      {'time_epoch': 1744794900,
#       'time': '2025-04-16 15:00',
#       'temp_c': 25.3,
#       'temp_f': 77.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 239,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.77,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 37,
#       'cloud': 84,
#       'feelslike_c': 25.4,
#       'feelslike_f': 77.7,
#       'windchill_c': 25.3,
#       'windchill_f': 77.5,
#       'heatindex_c': 25.4,
#       'heatindex_f': 77.7,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.9,
#       'gust_kph': 20.8,
#       'uv': 6.0},
#      {'time_epoch': 1744798500,
#       'time': '2025-04-16 16:00',
#       'temp_c': 24.9,
#       'temp_f': 76.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 310,
#       'wind_dir': 'NW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.77,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 38,
#       'cloud': 86,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 24.9,
#       'windchill_f': 76.9,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 5.0},
#      {'time_epoch': 1744802100,
#       'time': '2025-04-16 17:00',
#       'temp_c': 23.8,
#       'temp_f': 74.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 355,
#       'wind_dir': 'N',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.77,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 42,
#       'cloud': 15,
#       'feelslike_c': 24.8,
#       'feelslike_f': 76.6,
#       'windchill_c': 23.8,
#       'windchill_f': 74.8,
#       'heatindex_c': 24.8,
#       'heatindex_f': 76.6,
#       'dewpoint_c': 10.2,
#       'dewpoint_f': 50.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.9,
#       'uv': 6.0},
#      {'time_epoch': 1744805700,
#       'time': '2025-04-16 18:00',
#       'temp_c': 20.4,
#       'temp_f': 68.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 16,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.79,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 46,
#       'cloud': 15,
#       'feelslike_c': 20.4,
#       'feelslike_f': 68.8,
#       'windchill_c': 20.4,
#       'windchill_f': 68.8,
#       'heatindex_c': 20.4,
#       'heatindex_f': 68.8,
#       'dewpoint_c': 12.4,
#       'dewpoint_f': 54.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 6.0},
#      {'time_epoch': 1744809300,
#       'time': '2025-04-16 19:00',
#       'temp_c': 19.4,
#       'temp_f': 66.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 41,
#       'wind_dir': 'NE',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.81,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 12,
#       'feelslike_c': 19.4,
#       'feelslike_f': 66.9,
#       'windchill_c': 19.4,
#       'windchill_f': 66.9,
#       'heatindex_c': 19.4,
#       'heatindex_f': 66.9,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.1,
#       'uv': 0.0},
#      {'time_epoch': 1744812900,
#       'time': '2025-04-16 20:00',
#       'temp_c': 18.7,
#       'temp_f': 65.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 52,
#       'wind_dir': 'NE',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 9,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.6,
#       'windchill_c': 18.7,
#       'windchill_f': 65.6,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.6,
#       'dewpoint_c': 11.9,
#       'dewpoint_f': 53.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.9,
#       'gust_kph': 12.7,
#       'uv': 0.0},
#      {'time_epoch': 1744816500,
#       'time': '2025-04-16 21:00',
#       'temp_c': 17.9,
#       'temp_f': 64.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 49,
#       'wind_dir': 'NE',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 8,
#       'feelslike_c': 17.9,
#       'feelslike_f': 64.2,
#       'windchill_c': 17.9,
#       'windchill_f': 64.2,
#       'heatindex_c': 17.9,
#       'heatindex_f': 64.2,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.8,
#       'gust_kph': 10.9,
#       'uv': 0.0},
#      {'time_epoch': 1744820100,
#       'time': '2025-04-16 22:00',
#       'temp_c': 17.8,
#       'temp_f': 64.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 49,
#       'wind_dir': 'NE',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 9,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.1,
#       'windchill_c': 17.8,
#       'windchill_f': 64.1,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.1,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.3,
#       'uv': 0.0},
#      {'time_epoch': 1744823700,
#       'time': '2025-04-16 23:00',
#       'temp_c': 17.5,
#       'temp_f': 63.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 60,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 10,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.6,
#       'windchill_c': 17.5,
#       'windchill_f': 63.6,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.6,
#       'dewpoint_c': 11.1,
#       'dewpoint_f': 52.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.3,
#       'uv': 0.0}]}]}}

# %%
# Extracting the values
name = data['location']['name']
region = data['location']['region']
country = data['location']['country']
lat = data['location']['lat']
lon = data['location']['lon']
tz_id = data['location']['tz_id']
localtime_epoch = data['location']['localtime_epoch']
localtime = data['location']['localtime']

# %%
import pandas as pd 

# Extracting the hourly data
hourly_data = []

for hour in data["forecast"]["forecastday"][0]["hour"]:
    hourly_data.append({
        "name" : data['location']['name'],
        "region" : data['location']['region'],
        "country" : data['location']['country'],
        "lat" : data['location']['lat'],
        "lon" : data['location']['lon'],
        "tz_id" : data['location']['tz_id'],
        "localtime_epoch" : data['location']['localtime_epoch'],
        "localtime" : data['location']['localtime'],
        "time": hour["time"],
        "temp_c": hour["temp_c"],
        "temp_f": hour["temp_f"],
        "condition_text": hour["condition"]["text"],
        "condition_icon": hour["condition"]["icon"],
        "wind_mph": hour["wind_mph"],
        "wind_kph": hour["wind_kph"],
        "wind_degree": hour["wind_degree"],
        "wind_dir": hour["wind_dir"],
        "pressure_mb": hour["pressure_mb"],
        "pressure_in": hour["pressure_in"],
        "precip_mm": hour["precip_mm"],
        "precip_in": hour["precip_in"],
        "snow_cm": hour["snow_cm"],
        "humidity": hour["humidity"],
        "cloud": hour["cloud"],
        "feelslike_c": hour["feelslike_c"],
        "feelslike_f": hour["feelslike_f"],
        "windchill_c": hour["windchill_c"],
        "windchill_f": hour["windchill_f"],
        "heatindex_c": hour["heatindex_c"],
        "heatindex_f": hour["heatindex_f"],
        "dewpoint_c": hour["dewpoint_c"],
        "dewpoint_f": hour["dewpoint_f"],
        "will_it_rain": hour["will_it_rain"],
        "chance_of_rain": hour["chance_of_rain"],
        "will_it_snow": hour["will_it_snow"],
        "chance_of_snow": hour["chance_of_snow"],
        "vis_km": hour["vis_km"],
        "vis_miles": hour["vis_miles"],
        "gust_mph": hour["gust_mph"],
        "gust_kph": hour["gust_kph"],
        "uv": hour["uv"]
    })

# Create a DataFrame
df = pd.DataFrame(hourly_data)
df
# Out:
#          name region country      lat      lon           tz_id  \
# 0   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 1   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 2   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 3   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 4   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 5   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 6   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 7   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 8   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 9   Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 10  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 11  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 12  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 13  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 14  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 15  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 16  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 17  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 18  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 19  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 20  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 21  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 22  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
# 23  Kathmandu          Nepal  27.7167  85.3167  Asia/Kathmandu
#
#     localtime_epoch         localtime              time  temp_c  ...  \
# 0        1745397259  2025-04-23 14:19  2025-04-16 00:00    16.7  ...
# 1        1745397259  2025-04-23 14:19  2025-04-16 01:00    16.5  ...
# 2        1745397259  2025-04-23 14:19  2025-04-16 02:00    17.4  ...
# 3        1745397259  2025-04-23 14:19  2025-04-16 03:00    17.1  ...
# 4        1745397259  2025-04-23 14:19  2025-04-16 04:00    17.0  ...
# 5        1745397259  2025-04-23 14:19  2025-04-16 05:00    17.2  ...
# 6        1745397259  2025-04-23 14:19  2025-04-16 06:00    17.7  ...
# 7        1745397259  2025-04-23 14:19  2025-04-16 07:00    20.1  ...
# 8        1745397259  2025-04-23 14:19  2025-04-16 08:00    21.8  ...
# 9        1745397259  2025-04-23 14:19  2025-04-16 09:00    23.5  ...
# 10       1745397259  2025-04-23 14:19  2025-04-16 10:00    24.7  ...
# 11       1745397259  2025-04-23 14:19  2025-04-16 11:00    25.1  ...
# 12       1745397259  2025-04-23 14:19  2025-04-16 12:00    25.5  ...
# 13       1745397259  2025-04-23 14:19  2025-04-16 13:00    25.3  ...
# 14       1745397259  2025-04-23 14:19  2025-04-16 14:00    25.5  ...
# 15       1745397259  2025-04-23 14:19  2025-04-16 15:00    25.3  ...
# 16       1745397259  2025-04-23 14:19  2025-04-16 16:00    24.9  ...
# 17       1745397259  2025-04-23 14:19  2025-04-16 17:00    23.8  ...
# 18       1745397259  2025-04-23 14:19  2025-04-16 18:00    20.4  ...
# 19       1745397259  2025-04-23 14:19  2025-04-16 19:00    19.4  ...
# 20       1745397259  2025-04-23 14:19  2025-04-16 20:00    18.7  ...
# 21       1745397259  2025-04-23 14:19  2025-04-16 21:00    17.9  ...
# 22       1745397259  2025-04-23 14:19  2025-04-16 22:00    17.8  ...
# 23       1745397259  2025-04-23 14:19  2025-04-16 23:00    17.5  ...
#
#     dewpoint_f will_it_rain chance_of_rain  will_it_snow  chance_of_snow  \
# 0         51.4            0              0             0               0
# 1         50.9            0              0             0               0
# 2         46.7            0              0             0               0
# 3         46.2            0              0             0               0
# 4         46.2            0              0             0               0
# 5         46.4            0              0             0               0
# 6         52.2            0              0             0               0
# 7         53.1            0              0             0               0
# 8         52.8            0              0             0               0
# 9         52.4            1            100             0               0
# 10        52.1            1            100             0               0
# 11        51.5            1            100             0               0
# 12        47.8            1            100             0               0
# 13        48.6            1            100             0               0
# 14        49.3            1            100             0               0
# 15        49.4            1            100             0               0
# 16        49.4            1            100             0               0
# 17        50.4            0              0             0               0
# 18        54.2            0              0             0               0
# 19        53.8            0              0             0               0
# 20        53.4            0              0             0               0
# 21        52.6            0              0             0               0
# 22        52.6            0              0             0               0
# 23        52.0            0              0             0               0
#
#     vis_km vis_miles  gust_mph  gust_kph   uv
# 0     10.0       6.0       2.8       4.5  0.0
# 1     10.0       6.0       4.2       6.8  0.0
# 2     10.0       6.0       5.6       9.1  0.0
# 3     10.0       6.0       4.2       6.8  0.0
# 4     10.0       6.0       3.8       6.0  0.0
# 5     10.0       6.0       3.7       6.0  0.0
# 6     10.0       6.0       2.8       4.5  5.0
# 7     10.0       6.0       2.3       3.7  6.0
# 8     10.0       6.0       5.2       8.3  6.0
# 9     10.0       6.0       5.3       8.5  5.0
# 10    10.0       6.0       6.2      10.0  5.0
# 11    10.0       6.0       6.9      11.1  6.0
# 12    10.0       6.0       8.7      14.1  6.0
# 13    10.0       6.0       9.1      14.6  6.0
# 14    10.0       6.0      12.2      19.6  6.0
# 15    10.0       6.0      12.9      20.8  6.0
# 16    10.0       6.0      12.1      19.5  5.0
# 17    10.0       6.0      11.1      17.9  6.0
# 18    10.0       6.0      10.3      16.6  6.0
# 19    10.0       6.0       8.7      14.1  0.0
# 20    10.0       6.0       7.9      12.7  0.0
# 21    10.0       6.0       6.8      10.9  0.0
# 22    10.0       6.0       5.2       8.3  0.0
# 23    10.0       6.0       5.2       8.3  0.0
#
# [24 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['name', 'region', 'country', 'lat', 'lon', 'tz_id', 'localtime_epoch',
#        'localtime', 'time', 'temp_c', 'temp_f', 'condition_text',
#        'condition_icon', 'wind_mph', 'wind_kph', 'wind_degree', 'wind_dir',
#        'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'snow_cm',
#        'humidity', 'cloud', 'feelslike_c', 'feelslike_f', 'windchill_c',
#        'windchill_f', 'heatindex_c', 'heatindex_f', 'dewpoint_c', 'dewpoint_f',
#        'will_it_rain', 'chance_of_rain', 'will_it_snow', 'chance_of_snow',
#        'vis_km', 'vis_miles', 'gust_mph', 'gust_kph', 'uv'],
#       dtype='object')
